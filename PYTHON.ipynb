# %% [markdown]
# <a href="https://colab.research.google.com/github/milton012/python/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**aula 1:**  💪💙🥋
# ![image.png](data:image/png;base64,...)

# %%
print("I competição de programação dá Start")
ano = "IX"
print(ano, "competição de programação da Start")
# Out:
# I competição de programação dá Start
# IX competição de programação da Start

# %% [markdown]
# ##**aula 2**  ☠🥋❄

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_ana + pontos_rodrigo
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de Ana são {pontos_ana}")
print(f"Os pontos totais de Ana e rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de Ana são 46
# Os pontos totais de Ana e rodrigo são 70

# %% [markdown]
# **aula 4** 🧙‍♂️❄️🥶

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 35
# 35 x 1 = 35
# 35 x 2 = 70
# 35 x 3 = 105
# 35 x 4 = 140
# 35 x 5 = 175
# 35 x 6 = 210
# 35 x 7 = 245
# 35 x 8 = 280
# 35 x 9 = 315
# 35 x 10 = 350

# %% [markdown]
# **aula  5**🤴🟦🏰

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} / {contador} = {numero / contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 3
# 3 / 1 = 3.0
# 3 / 2 = 1.5
# 3 / 3 = 1.0
# 3 / 4 = 0.75
# 3 / 5 = 0.6
# 3 / 6 = 0.5
# 3 / 7 = 0.42857142857142855
# 3 / 8 = 0.375
# 3 / 9 = 0.3333333333333333
# 3 / 10 = 0.3

# %% [markdown]
# ** aula 6** 🤴🟥🏰

# %%
print ("Salve, sou teu parceiro de caminhada")
nome = input("Qual teu vulgo truta?: ")
print (f"Iae {nome}, qual é a fita?")
resposta = input ( "quer falar sobre python, javascript ou matematica mano?: ").lower()
if resposta=="python":
  print(f"fecho meu mano {nome} vamos fala sobre Python! \n Python é uma linguagem de programação simples, versátil e poderosa, ideal para iniciantes e usada em áreas como desenvolvimento web, ciência de dados e automação. Sua sintaxe clara e ampla biblioteca padrão a tornam uma das mais populares do mundo.")
elif resposta=="javascript":
  print(f"fecho meu mano{nome} vamos fala sobre javascript! \n JavaScript é uma linguagem de programação essencial para o desenvolvimento web, permitindo criar interatividade e dinamicidade em sites. Usada tanto no front-end (navegador) quanto no back-end (com Node.js), é uma das linguagens mais populares e versáteis da web.")
elif resposta=="matemática":
   print(f"fecho meu mano{nome} vamos falar sobre matemática! \n Matemática é a ciência que estuda números, formas, padrões e suas relações, utilizando lógica e abstração. Ela é fundamental para diversas áreas do conhecimento, como física, economia e engenharia.")
else:
  print(f"Que pena{nome} vamos falar sobre matemática!")
# Out:
# Salve, sou teu parceiro de caminhada

# %% [markdown]
# **aula 7** 🙅‍♂️👑🥇

# %%
import random
dica = [
"O sucesso começa no primeiro passo. Levante-se e comece a semana com a mentalidade de um campeão!"💪🏆,
"A dor é temporária, mas a honra de superar os desafios permanece para sempre.🔥🥋",
"Meia semana é o momento perfeito para reforçar o foco. O que você faz hoje determina onde você estará amanhã.🎯💥",
"O adversário mais difícil é aquele que você encontra no espelho. Derrote suas próprias limitações e vá além.🪞👊"",
"Toda vitória começa com um treino. Dedicação e perseverança criam campeões.🏅💯",
"Estude cada técnica para aprimorar o que você não fez bem. Cada erro é uma lição, cada lição, uma oportunidade de crescimento.📚💡",
"Descansar é parte da jornada, mas o descanso não é sinônimo de desistência. Prepare-se mental e fisicamente para a próxima batalha.🛌⚔️",



]
while true:
  pedido = input("digite 'dica para receber uma dica ou 'sair' para encerrar \n "). lower()

  if pedido == "dica":
    dica = random.choice(dica) # escolhe uma dica aleatória sair
    print(f"Dica:{dica} \n ")
    break
  elif pedido == "sair":
    print("Até a próxima! \n")
    break
  else:
    print("comando inválido. Tente novamente. \n")
    break
